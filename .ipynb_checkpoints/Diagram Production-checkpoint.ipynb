# %% [markdown]
# The purpose of this notebook is for the production of the diagrams.

# %%
# %matplotlib inline
from TriangleFunctions import *

# %% [markdown]
# Test out ideas and diagrams below

# %%
val1 = 42
val2 = (180-val1)/2
eq_triangle = return_points(val1, val2, [1, 0])
visited_points = drawTriangle(120, [0.1, 0], eq_triangle, [0, 15])

# %%
eq_triangle = return_points(30, 66, [1, 0])
visited_points = drawTriangle(120, [0.2, 0], eq_triangle, [0, 120])
